# %% [markdown]
# <a href="https://colab.research.google.com/github/sadaf21/CodSoft/blob/main/TASK1_CODSOFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 1 - TITANIC SURVIVAL PREDICTION
# INTERN - SADAF KHURSHID
# DOMAIN - DATA SCIENCE
# BATCH - AUGUST
# OBJECTIVE - TO ANALYSE THE DATASET TO PREDICT WHETHER THE PASSENGER IS SURVIVED OR NOT.

# %% [markdown]
# IMPORTING LIBRARIES TO BE USED

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# IMPORTING CSV

# %%
df = pd.read_csv("titanic.csv")
df.head(10)
# Out:
#       PassengerId  Survived                                        Pclass  \
# (892            0         3                                       'Kelly'
# 893             1         3              Wilkes, Mrs. James (Ellen Needs)
# 894             0         2                     Myles, Mr. Thomas Francis
# 895             0         3                              Wirz, Mr. Albert
# 896             1         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897             0         3                    Svensson, Mr. Johan Cervin
# 898             1         3                          Connolly, Miss. Kate
# 899             0         2                  Caldwell, Mr. Albert Francis
# 900             1         3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901             0         3                       Davies, Mr. John Samuel
#
#               Name   Sex   Age  SibSp      Parch       Ticket    Fare Cabin  \
# (892   'Mr. James'  male  34.5      0          0  330911.0000  7.8292   NaN
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived         Age       SibSp         Ticket
# count   418.000000  418.000000  418.000000  418.000000     417.000000
# mean      0.363636    2.265550    0.529904    0.392344     829.159972
# std       0.481622    0.841838    1.891465    0.981429   16203.129841
# min       0.000000    1.000000    0.000000    0.000000       0.000000
# 25%       0.000000    1.000000    0.000000    0.000000       7.895800
# 50%       0.000000    3.000000    0.000000    0.000000      14.454200
# 75%       1.000000    3.000000    1.000000    0.000000      31.500000
# max       1.000000    3.000000   34.500000    9.000000  330911.000000

# %% [markdown]
# THERE ARE SOME MISSING VALUES IN AGE

# %%
df['Survived'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Survived, dtype: int64

# %% [markdown]
# LET'S ASSUME SURVIVALS WITH RESPECT TO PCLASS

# %%
sns.countplot(x=df['Survived'], hue=df['Pclass'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Sex']
# Out:
# (892    male
# 893       47
# 894       62
# 895       27
# 896       22
#         ...
# 1305     NaN
# 1306      39
# 1307    38.5
# 1308     NaN
# 1309     NaN
# Name: Sex, Length: 418, dtype: object

# %% [markdown]
# LET'S ASSUME THE COUNT OF SURVIVALS WITH RESPECT TO GENDER

# %%
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.groupby('Sex')[['Survived']].mean()
# Out:
#       Survived
# Sex
# 0.17       3.0
# 0.33       3.0
# 0.75       3.0
# 0.83       3.0
# 0.92       2.0
# ...        ...
# 7          3.0
# 76         1.0
# 8          2.0
# 9          3.0
# male       3.0
#
# [79 rows x 1 columns]

# %%
df['Sex'].unique()
# Out:
# array(['male', '47', '62', '27', '22', '14', '30', '26', '18', '21', nan,
#        '46', '23', '63', '24', '35', '45', '55', '9', '48', '50', '22.5',
#        '41', '33', '18.5', '25', '39', '60', '36', '20', '28', '10', '17',
#        '32', '13', '31', '29', '28.5', '32.5', '6', '67', '49', '2', '76',
#        '43', '16', '1', '12', '42', '53', '26.5', '40', '61', '60.5', '7',
#        '15', '54', '64', '37', '34', '11.5', '8', '0.33', '38', '57',
#        '40.5', '0.92', '19', '36.5', '0.75', '0.83', '58', '0.17', '59',
#        '14.5', '44', '5', '51', '3', '38.5'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Sex']= labelencoder.fit_transform(df['Sex'])
df.head()
# Out:
#       PassengerId  Survived                                        Pclass  \
# (892            0         3                                       'Kelly'
# 893             1         3              Wilkes, Mrs. James (Ellen Needs)
# 894             0         2                     Myles, Mr. Thomas Francis
# 895             0         3                              Wirz, Mr. Albert
# 896             1         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#               Name  Sex   Age  SibSp    Parch       Ticket    Fare Cabin  \
# (892   'Mr. James'   78  34.5      0        0  330911.0000  7.8292   NaN
# 893         female   54   1.0      0   363272       7.0000     NaN     S
# 894           male   70   0.0      0   240276       9.6875     NaN     Q
# 895           male   28   0.0      0   315154       8.6625     NaN     S
# 896         female   21   1.0      1  3101298      12.2875     NaN     S
#
#      Embarked
# (892      Q);
# 893       NaN
# 894       NaN
# 895       NaN
# ...

# %%
df['Sex'], df['Survived']
# Out:
# ((892    78
#  893     54
#  894     70
#  895     28
#  896     21
#          ..
#  1305    79
#  1306    45
#  1307    44
#  1308    79
#  1309    79
#  Name: Sex, Length: 418, dtype: int64,
#  (892    3
#  893     3
#  894     2
#  895     3
#  896     3
#         ..
#  1305    3
#  1306    1
#  1307    3
#  1308    3
#  1309    3
#  Name: Survived, Length: 418, dtype: int64)

# %%
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           1
# Fare           326
# Cabin            1
# Embarked       417
# dtype: int64

# %%
df=df.drop(['Age'], axis=1)

# %%
df_final = df
df_final.head(10)
# Out:
#       PassengerId  Survived                                        Pclass  \
# (892            0         3                                       'Kelly'
# 893             1         3              Wilkes, Mrs. James (Ellen Needs)
# 894             0         2                     Myles, Mr. Thomas Francis
# 895             0         3                              Wirz, Mr. Albert
# 896             1         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897             0         3                    Svensson, Mr. Johan Cervin
# 898             1         3                          Connolly, Miss. Kate
# 899             0         2                  Caldwell, Mr. Albert Francis
# 900             1         3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901             0         3                       Davies, Mr. John Samuel
#
#               Name  Sex  SibSp      Parch       Ticket    Fare Cabin Embarked
# ...

# %%
X= df[['Pclass', 'Sex']]
Y= df['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state =0)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(random_state = 0)

# %%
log.fit(X_train, Y_train)

# %%
pred = print(log.predict(X_test))

# %%
print(Y_test)
# Out:
# 1252    3
# 1062    3
# 1116    1
# 1250    3
# 1201    3
#        ..
# 992     1
# 899     2
# 914     1
# 960     1
# 1220    2
# Name: Survived, Length: 84, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")
res = log.predict([[2,0]])
if(res==0):
  print("NOT SURVIVED")
else:
  print("SURVIVED")
